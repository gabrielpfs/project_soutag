# %% [markdown]
# # EDA - Netflix Movies and TV Shows
# **Objetivo:** Explorar e analisar o dataset bruto de títulos da Netflix, verificando qualidade dos dados, distribuição de colunas, padrões e insights iniciais.

# %%
# Manipulação de dados
import pandas as pd
import numpy as np

# Conexão com PostgreSQL
from sqlalchemy import create_engine
import os
from dotenv import load_dotenv

# Visualização
import matplotlib.pyplot as plt
import seaborn as sns

# Configuração estética para gráficos
sns.set_style("whitegrid")
plt.rcParams['figure.figsize'] = (12,6)

# Carregar variáveis de ambiente
load_dotenv('../env/.env')

# Conexão com PostgreSQL
user = os.getenv("DB_USER")
password = os.getenv("DB_PASSWORD")
host = os.getenv("DB_HOST")
port = os.getenv("DB_PORT")
database = os.getenv("DB_NAME")

engine = create_engine(f'postgresql+psycopg2://{user}:{password}@{host}:{port}/{database}')
